# %%
print("Hello Python!")
# Out:
# Hello Python!

# %%
print(123,"我是int")
print(456.123, '我是float')
print("字串","這是str")
print(True, "我是bool值")
# Out:
# 123 我是int
# 456.123 我是float
# 字串 這是str
# True 我是bool值
# Bad pipe message: %s [b"x\xdd#\xfe,S\x94N\xa2\xf6,Ec-\xb6\xe1\xc5/ \x80\xfa\xc4w\xeb\xc4\x9dmm\xdb*\x8c\xbd\xea\x96\x16\xe7\xbe'\xcd\xff\x14\x19\xc6\xd0b\x8f\xdc\xe2k\xfcX\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00", b'\x0c\x00\n\x00\x1d\x00\x17\x00\x1e']
# Bad pipe message: %s [b'\xd8\xaa\xb4Y\x17\xf5K\xfb\x8c\xef\xa8\xe1\xbev\xe3\xc6\x17] \x08x@7k\x8c1\x13\xf5\xaf\xa7,f\xa2\x1ba\xf2\x1e2\x84\xb4\x9bs`\x89k\xeb\xca\xdf\x01L\x98\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00', b'\x03\x04']
# ...
